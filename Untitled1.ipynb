# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
from fredapi import Fred
plt.style.use("fivethirtyeight")
color_pal = plt.rcParams['axes.prop_cycle'].by_key()['color']
print(color_pal)

api_key = 'b3bbf29e047354711724663744275086 '

# pd.set_option('max_columns',50)
# Out:
# ['#008fd5', '#fc4f30', '#e5ae38', '#6d904f', '#8b8b8b', '#810f7c']

# %%
fred = Fred(api_key=api_key)
fred

# %%
# bcz S&P 500 is on fred -- we'll work on this dataframe
# It helps people understand and analyze economic and financial information.

sp_search = fred.search('S&P',order_by="popularity")

# fred has limit so that we can't access unlimited data -- so it is 1000,15

print(sp_search.shape)

sp_search
# Out:
# (1000, 15)
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2023-09-16   2023-09-16
# CSUSHPINSA              CSUSHPINSA     2023-09-16   2023-09-16
# MEHOINUSA672N        MEHOINUSA672N     2023-09-16   2023-09-16
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2023-09-16   2023-09-16
# SP500                        SP500     2023-09-16   2023-09-16
# ...                            ...            ...          ...
# DDDM02ILA156NWDB  DDDM02ILA156NWDB     2023-09-16   2023-09-16
# DDDM02MUA156NWDB  DDDM02MUA156NWDB     2023-09-16   2023-09-16
# DDEM01ILA156NWDB  DDEM01ILA156NWDB     2023-09-16   2023-09-16
# DDEM01JOA156NWDB  DDEM01JOA156NWDB     2023-09-16   2023-09-16
# DDEM01QAA156NWDB  DDEM01QAA156NWDB     2023-09-16   2023-09-16
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# CSUSHPINSA          S&P/Case-Shiller U.S. National Home Price Index
# MEHOINUSA672N     Real Median Household Income in the United States
# BAMLH0A0HYM2EY         ICE BofA US High Yield Index Effective Yield
# SP500                                                       S&P 500
# ...                                                             ...
# DDDM02ILA156NWDB  Stock Market Total Value Traded to GDP for Israel
# DDDM02MUA156NWDB  Stock Market Total Value Traded to GDP for Mau...
# DDEM01ILA156NWDB  Stock Market Turnover Ratio (Value Traded/Capi...
# DDEM01JOA156NWDB  Stock Market Turnover Ratio (Value Traded/Capi...
# DDEM01QAA156NWDB  Stock Market Turnover Ratio (Value Traded/Capi...
#
#                  observation_start observation_end     frequency  \
# series id
# BAMLH0A0HYM2            1996-12-31      2023-09-14  Daily, Close
# CSUSHPINSA              1987-01-01      2023-06-01       Monthly
# MEHOINUSA672N           1984-01-01      2022-01-01        Annual
# BAMLH0A0HYM2EY          1996-12-31      2023-09-14  Daily, Close
# SP500                   2013-09-16      2023-09-15  Daily, Close
# ...                            ...             ...           ...
# DDDM02ILA156NWDB        1995-01-01      2020-01-01        Annual
# DDDM02MUA156NWDB        1993-01-01      2020-01-01        Annual
# DDEM01ILA156NWDB        1995-01-01      2020-01-01        Annual
# DDEM01JOA156NWDB        2007-01-01      2020-01-01        Annual
# DDEM01QAA156NWDB        2007-01-01      2020-01-01        Annual
#
#                  frequency_short                           units  \
# series id
# BAMLH0A0HYM2                   D                         Percent
# CSUSHPINSA                     M              Index Jan 2000=100
# MEHOINUSA672N                  A  2021 CPI-U-RS Adjusted Dollars
# BAMLH0A0HYM2EY                 D                         Percent
# SP500                          D                           Index
# ...                          ...                             ...
# DDDM02ILA156NWDB               A                         Percent
# DDDM02MUA156NWDB               A                         Percent
# DDEM01ILA156NWDB               A                         Percent
# DDEM01JOA156NWDB               A                         Percent
# DDEM01QAA156NWDB               A                         Percent
#
#                                units_short      seasonal_adjustment  \
# series id
# BAMLH0A0HYM2                             %  Not Seasonally Adjusted
# CSUSHPINSA              Index Jan 2000=100  Not Seasonally Adjusted
# MEHOINUSA672N     2021 CPI-U-RS Adjusted $  Not Seasonally Adjusted
# BAMLH0A0HYM2EY                           %  Not Seasonally Adjusted
# SP500                                Index  Not Seasonally Adjusted
# ...                                    ...                      ...
# DDDM02ILA156NWDB                         %  Not Seasonally Adjusted
# DDDM02MUA156NWDB                         %  Not Seasonally Adjusted
# DDEM01ILA156NWDB                         %  Not Seasonally Adjusted
# DDEM01JOA156NWDB                         %  Not Seasonally Adjusted
# DDEM01QAA156NWDB                         %  Not Seasonally Adjusted
#
#                  seasonal_adjustment_short               last_updated  \
# series id
# BAMLH0A0HYM2                           NSA  2023-09-15 08:00:12-05:00
# CSUSHPINSA                             NSA  2023-08-29 08:11:02-05:00
# MEHOINUSA672N                          NSA  2023-09-12 13:48:02-05:00
# BAMLH0A0HYM2EY                         NSA  2023-09-15 08:00:16-05:00
# SP500                                  NSA  2023-09-15 19:11:01-05:00
# ...                                    ...                        ...
# DDDM02ILA156NWDB                       NSA  2022-03-23 16:32:16-05:00
# DDDM02MUA156NWDB                       NSA  2022-03-23 16:32:15-05:00
# DDEM01ILA156NWDB                       NSA  2022-03-23 16:28:54-05:00
# DDEM01JOA156NWDB                       NSA  2022-08-04 09:48:41-05:00
# DDEM01QAA156NWDB                       NSA  2022-08-04 09:48:40-05:00
#
#                  popularity                                              notes
# series id
# BAMLH0A0HYM2             94  The ICE BofA Option-Adjusted Spreads (OASs) ar...
# CSUSHPINSA               90  For more information regarding the index, plea...
# MEHOINUSA672N            84  Household data are collected as of March.  As ...
# BAMLH0A0HYM2EY           83  This data represents the effective yield of th...
# SP500                    83  The observations for the S&P 500 represent the...
# ...                     ...                                                ...
# DDDM02ILA156NWDB          3  Total value of all traded shares in a stock ma...
# DDDM02MUA156NWDB          3  Total value of all traded shares in a stock ma...
# DDEM01ILA156NWDB          3  Total value of shares traded during the period...
# DDEM01JOA156NWDB          3  Total value of shares traded during the period...
# DDEM01QAA156NWDB          3  Total value of shares traded during the period...
#
# [1000 rows x 15 columns]
